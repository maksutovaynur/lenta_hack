# %%
import predictions as P
import ipywidgets as W
import pandas as pd
from datetime import datetime, timedelta
from importlib import reload
import traceback
from IPython.display import display, HTML
display(HTML("<style>.container{width: 100%}</style>"))
P = reload(P)
# Out:
# <style>.container{width: 100%}</style>

# %%
data = P.read_preproc_cut_transcations_data(path="./.data/transactions.parquet")
dC_raw = pd.read_csv("./.data/clients.csv")
dP_raw = pd.read_csv("./.data/plants.csv")
dM_raw = pd.read_csv("./.data/materials.csv")

# %%
desc = data.describe()

# %%
data["chq_date"].max()
# Out:
# Timestamp('2017-08-25 00:00:00')

# %%
def show_predictions(shop_id, product_id, today):
    display("Start recalculate")
    return P.predict_demand(data, shop_id=shop_id, product_id=product_id, current_date=today)

# %%
W.interactive(
    show_predictions, 
    {'manual': True}, 
    shop_id=W.IntSlider(min=0, max=desc["shop_id"]["max"], value=40),
    product_id=W.IntSlider(min=0, max=desc["product_id"]["max"], value=100),
    today=W.DatePicker(
        value=data["chq_date"].max() - timedelta(days=30), 
        style=dict(min=data["chq_date"].min(), max=data["chq_date"].max())
    ),
)
# Out:
# interactive(children=(IntSlider(value=40, description='shop_id', max=382), IntSlider(value=100, description='p…

# %%
help(W.DatePicker)
# Out:
# Help on class DatePicker in module ipywidgets.widgets.widget_date:
#
# class DatePicker(ipywidgets.widgets.widget_description.DescriptionWidget, ipywidgets.widgets.valuewidget.ValueWidget, ipywidgets.widgets.widget_core.CoreWidget)
#  |  DatePicker(*args, **kwargs)
#  |
#  |  Display a widget for picking dates.
#  |
#  |  Parameters
#  |  ----------
#  |
#  |  value: datetime.date
#  |      The current value of the widget.
#  |
#  |  disabled: bool
#  |      Whether to disable user changes.
#  |
#  |  Examples
#  |  --------
#  |
#  |  >>> import datetime
#  |  >>> import ipywidgets as widgets
#  |  >>> date_pick = widgets.DatePicker()
#  |  >>> date_pick.value = datetime.date(2019, 7, 9)
#  |
#  |  Method resolution order:
#  |      DatePicker
#  |      ipywidgets.widgets.widget_description.DescriptionWidget
#  |      ipywidgets.widgets.domwidget.DOMWidget
#  |      ipywidgets.widgets.valuewidget.ValueWidget
#  |      ipywidgets.widgets.widget_core.CoreWidget
# ...
